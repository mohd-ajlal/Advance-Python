# %%
import os
from os import path
import shutil
from zipfile import ZipFile

# %%
shutil.copy("text.txt", "backup.txt")
# Out:
# 'backup.txt'

# %%
os.rename("backup.txt", "newtext.txt")

# %%
shutil.make_archive("archive", "zip", "folder_path")
# Out:
# 'd:\\Python\\Python\\working with files\\archive.zip'

# %%
with ZipFile("files.zip", "w") as zipf:
    zipf.write("text.txt")
    zipf.write("newtext.txt")

# %%
print(path.realpath("text.txt"))
# Out:
# D:\Python\Python\working with files\text.txt

# %%
print(path.exists("text.txt"))
# Out:
# True

# %%
if path.exists("text.txt"):
    # get the path to the file in the current directory
    src = path.realpath("text.txt");
        
    # # let's make a backup copy by appending "bak" to the name
    dst = src + ".bak"
    # # now use the shell to make a copy of the file
    shutil.copy(src,dst)

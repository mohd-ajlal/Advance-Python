# %% [markdown]
# Functions

# %%
# Funtion in Python
# A function is a reusable block of code that performs a specific task. It allows you to organize your code, improve readability, and avoid repetition. In Python, you can define a function using the `def` keyword followed by the function name and parentheses.

# Syntax:
# def function_name(parameters):
#     # function body

# %%
name = "Ajlal"

def greet(name):
    return f"Hello, {name}!"

# %%
print(greet(name))
# Out:
# Hello, Ajlal!

# %%
# Function with variable number of parameters

# What if you want to create a function that can accept a variable number of arguments? You can use the `*args` syntax to achieve this. The `*args` allows you to pass a variable number of non-keyword arguments to a function.
# Example:

def greet_all(*names):
    for name in names:
        print(f"Hello, {name}!")
greet_all("Alice", "Bob", "Charlie")
# Out:
# Hello, Alice!
# Hello, Bob!
# Hello, Charlie!

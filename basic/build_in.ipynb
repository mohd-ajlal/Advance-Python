# %% [markdown]
# Build-In Function

# %%
myStr = "Hello"
print(len(myStr))
# Out:
# 5

# %%
myList = [3,2,5,1,7,5,9]
print(max(myList))
print(min(myList))
# Out:
# 9
# 1

# %%
mySytr = "Hello World"
num = 5

print(str(num) + " " + mySytr)
# Out:
# 5 Hello World

# %%
# range(start, stop, step)

for i in range(0, 10, 2):
    print(i, end=" ")
# Out:
# 0 2 4 6 8

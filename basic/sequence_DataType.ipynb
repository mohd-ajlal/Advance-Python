# %%
# List

myList = [1, 2, 3, 4, 5]
print(myList)
# Out:
# [1, 2, 3, 4, 5]

# %%
myList.append(6)
print(myList)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x = 256
y = 256
print(x is y)
# Out:
# True

# %%
x = 1000
y = 1000
print(x is y) # This may return False because of how Python handles small integers (interning), but for larger integers, it may create separate objects.
# Out:
# False

# %%
print(myList[1])
# Out:
# 2

# %%
myList[-1]
# Out:
# 6

# %%
myList[0] = 10
print(myList)
# Out:
# [10, 2, 3, 4, 5, 6]

# %%
MyL = [1 , "Hello" , True , 3.14]

# %%
MyL
# Out:
# [1, 'Hello', True, 3.14]

# %%
# add list

newL = myList + MyL
print(newL)
# Out:
# [10, 2, 3, 4, 5, 6, 1, 'Hello', True, 3.14]

# %%
# len
print(len(myList))

# %%
# Slicing

print(myList[1:4]) # This will print elements from index 1 to 3 (4 is exclusive)
# Out:
# [2, 3, 4]

# %%
# use slice to get part of sequence

print(myList[::2]) # This will print every second element of the list, starting from index 0.
# Out:
# [10, 3, 5]

# %%
# reverse list

print(myList[::-1]) # This will print the list in reverse order.
# Out:
# [6, 5, 4, 3, 2, 10]

# %%
myList
# Out:
# [10, 2, 3, 4, 5, 6]

# %%
# Tuple

myTuple = (1, 2, 3, 4, 5)
print(myTuple)
# Out:
# (1, 2, 3, 4, 5)

# %%
print(myTuple[1])
# Out:
# 2

# %%
# difference between list and tuple
# 1. Mutability: Lists are mutable, meaning you can change their content after creation (e.g., add, remove, or modify elements). Tuples are immutable, meaning once they are created, their content cannot be changed.
# 2. Syntax: Lists are defined using square brackets [] while tuples are defined using parentheses
# 3. Performance: Tuples can be more memory efficient and faster than lists due to their immutability, especially when dealing with large collections of data.

# %%
# Sets

mySet = {1, 2, 3, 4, 5}
print(mySet)
# Out:
# {1, 2, 3, 4, 5}

# %%
mySet = {1,2,5,2,4,'Hello'}
print(mySet) # This will print the set without duplicates and in an unordered manner.
# Out:
# {1, 2, 4, 5, 'Hello'}

# %%
# index not supported in set because it is unordered collection of unique elements.

# %%
# Test for membership

print(3 in myList) # This will return True because 3 is in myList.
print(10 in myTuple) # This will return False because 10 is not in myTuple.
print('Hello' in mySet) # This will return True because 'Hello' is in mySet.
# Out:
# True
# False
# True

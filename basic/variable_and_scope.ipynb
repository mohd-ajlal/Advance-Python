# %%
def performOperation(*args, **kwargs):
    print(args)
    print(kwargs)

performOperation(1, 2, operation='sum')
# Out:
# (1, 2)
# {'operation': 'sum'}

# %%
def performOperation(num1, num2, operation='sum'):
    print(locals())
    
performOperation(1, 2, operation='multiply')
# Out:
# {'num1': 1, 'num2': 2, 'operation': 'multiply'}

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': '\nNote: all executions are function-scoped as we do not assume the code below executes in an isolated kernel environment.\n',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#   "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n    \nperformOperation(1, 2, operation='multiply')",
#   'globals()',
#   'globals()'],
#  '_oh': {2: 'ok', 3: {...}},
#  '_dh': [WindowsPath('d:/Python/Python/basic')],
#  'In': ['',
#   "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#   "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n    \nperformOperation(1, 2, operation='multiply')",
#   'globals()',
#   'globals()'],
#  'Out': {2: 'ok', 3: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001FBC515DCF0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1fbc515e2c0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1fbc515e2c0>,
#  '_': {...},
#  '__': 'ok',
#  '___': 'ok',
#  '__vsc_ipynb_file__': 'd:\\Python\\Python\\basic\\variable_and_scope.ipynb',
#  '__DW_SCOPE__': {'output_cache': {},
#   'output-0c976fcc-e23f-4c3a-8b4f-8a18d4ab9fe7': {'enable_for_types': <function __main__.__DW_OUTPUT_FORMATTER__.<locals>.enable_formatter_for_types(*args)>,
#    'disable': <function __main__.__DW_OUTPUT_FORMATTER__.<locals>.disable_formatter()>}},
#  '_i': '\n\nglobals()',
#  '_ii': "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n    \nperformOperation(1, 2, operation='multiply')",
#  '_iii': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#  '_i1': "def performOperation(*args, **kwargs):\n    print(args)\n    print(kwargs)\n\nperformOperation(1, 2, operation='sum')",
#  'performOperation': <function __main__.performOperation(num1, num2, operation='sum')>,
#  '_2': 'ok',
#  '_i2': "def performOperation(num1, num2, operation='sum'):\n    print(locals())\n    \nperformOperation(1, 2, operation='multiply')",
#  '_i3': '\n\nglobals()',
#  '_3': {...},
#  '_i4': 'globals()'}

# %%
message = 'Some global data'

def function1(varA, varB):
    print(message)
    print(locals())
    
    
def function2(varC, varB):
    print(message)
    print(locals())
    
function1(1, 2)
function2(3, 4)
# Out:
# Some global data
# {'varA': 1, 'varB': 2}
# Some global data
# {'varC': 3, 'varB': 4}

# %%
message = 'Some global data'
varA = 2
def function1(varA, varB):
    message = 'Some local data'
    print(varA)
    print(message)
    print(locals())
    
    
def function2(varC, varB):
    print(varA)
    print(message)
    print(locals())
    
function1(1, 2)
function2(3, 4)
# Out:
# 1
# Some local data
# {'varA': 1, 'varB': 2, 'message': 'Some local data'}
# 2
# Some global data
# {'varC': 3, 'varB': 4}

# %%
def function1(varA, varB):
    message = 'Some local data'
    print(varA)
    def inner_function(varA, varB):
        print(f'inner_function local scope: {locals()}')
        
    inner_function(123, 456)
    

function1(1, 2)
# Out:
# 1
# inner_function local scope: {'varA': 123, 'varB': 456}

# %%
def function1(varA, varB):
    message = 'Some local data'
    print(varA)
    def inner_function(varA, varB):
        print(f'inner_function local scope: {locals()}')
    
    print(locals())
    inner_function(123, 456)
    

function1(1, 2)
# Out:
# 1
# {'varA': 1, 'varB': 2, 'message': 'Some local data', 'inner_function': <function function1.<locals>.inner_function at 0x000001FBC5202D40>}
# inner_function local scope: {'varA': 123, 'varB': 456}

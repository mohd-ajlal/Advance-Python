# %%
print("Hello World")
# Out:
# Hello World

# %%
name = input("What is your name? ")
print("Hello " + name)
# Out:
# Hello ajlal

# %%
1.2 - 1
# Out:
# 0.19999999999999996

# %%
bool(-1) == 1
# Out:
# True
